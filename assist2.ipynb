# %%
import assist_




clientName = input("|--Please enter your name: --|")
print("---------------------------------------")
print(f"|--Hi {clientName}, how can I help you today?--|")
print("---------------------------------------")

def main():
    print("\n-- Main Menu --")
    for _ in ["1. Math", "2. Game", "3. Book Recommendation", "4. Movie Recommendation", "5. Joke", "6. Time", "7. exit"]:
        print(_)
    while True:
        choice = input("Choose an option: ")

        if choice == "1":
            print("\n-- Math Menu --")
            for _ in ["1. calculator", "2. Check Prime #", "3. Decimal 2 Binarry", "4. Roman 2 Decimal"]:
                print(_)
            assist_.doMath(clientName)

        elif choice == "2":
            assist_.playGame(clientName)

        elif choice == "3":
            assist_.bookRecommendation(clientName)

        elif choice == "4":
            assist_.movieRecommendation(clientName)

        elif choice == "5":
            assist_.tellAJokes(clientName)

        elif choice == "6":
            assist_.stime(clientName)

        elif choice == "7":
            print("Goodbye...")
            break

        else:
            print("Invalid choice")

if __name__ == "__main__":
    main()
# Out:
# |--Please enter your name: --| Joe
# ---------------------------------------
# |--Hi Joe, how can I help you today?--|
# ---------------------------------------
#
# -- Main Menu --
# 1. Math
# 2. Game
# 3. Book Recommendation
# 4. Movie Recommendation
# 5. Joke
# 6. Time
# 7. exit
# Choose an option:  2
# Enter 1 for Number Guessing or 2 for Rock-Paper-Scisors
# Do you want to play 'Number guessing' or 'Rock-Paper-Scisor'? 1
# ----------------------------------------------------------
# |--Plese enter a number to guess range from 0 to 10: --| 5
# ----------------------------------------------------------
# Was: 1
# 5, is too large
# ----------------------------------------------------------
# |--Plese enter a number to guess range from 0 to 10: --| 4
# ----------------------------------------------------------
# Was: 4
# Congratulations Joe, 4 is the right guess:)
# You did it after 2 guess(es)
# --------------------
# Enter 1 for Number Guessing or 2 for Rock-Paper-Scisors
# ...
